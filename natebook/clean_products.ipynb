# %%
# import 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
products = pd.read_csv('C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/products.csv')
products.head()
# Out:
#   product_id                product_name     category  sub_category  \
# 0  PROD16267    Luxury US Polo Education        Books     Education
# 1  PROD08242    Luxury Syska Smart Watch  Electronics   Smart Watch
# 2  PROD18107  Max Mamaearth Men Clothing      Fashion  Men Clothing
# 3  PROD07986      Eco Casio Men Clothing      Fashion  Men Clothing
# 4  PROD01867           Elite Casio Decor         Home         Decor
#
#        brand vendor_id  cost_price  selling_price
# 0    US Polo  VEND0141    34811.71       42175.85
# 1      Syska  VEND0020    44549.77       50885.80
# 2  Mamaearth  VEND0121    17607.48       19797.94
# 3      Casio  VEND0032    10723.13       15908.78
# 4      Casio  VEND0182    34893.03       43920.80
