# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import datetime as dt

# %%
# load the file
promotions = pd.read_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/promotions.csv")

# %%
# export the data into sql 
USER = "root"
PASSWORD = "Abhi8383055393"
HOST = "localhost"
PORT = "3306"
DATABASE = "ecommmerce_analysis"

# %%
conn_str = f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"

# %%
mysql_eng = create_engine(conn_str)

# %%
promotions.to_sql("promotions",mysql_eng,if_exists='replace',index=False)
# Out:
# 500

# %%
promotions['start_date'] = pd.to_datetime(promotions['start_date'])

# %%
promotions['end_date'] = pd.to_datetime(promotions['end_date'])

# %%
promotions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   promotion_id         500 non-null    int64
#  1   promotion_name       500 non-null    object
#  2   promotion_type       500 non-null    object
#  3   discount_percentage  500 non-null    int64
#  4   status               500 non-null    object
#  5   start_date           500 non-null    datetime64[ns]
#  6   end_date             500 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 27.5+ KB

# %%
promotions['end_date'].value_counts()
# Out:
# end_date
# 2024-02-26    4
# 2025-10-13    3
# 2022-02-26    3
# 2021-05-24    3
# 2024-06-29    3
#              ..
# 2021-03-12    1
# 2021-12-23    1
# 2024-04-03    1
# 2021-07-29    1
# 2021-03-11    1
# Name: count, Length: 435, dtype: int64

# %%
promotions.to_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/promotions.csv", index=False)
