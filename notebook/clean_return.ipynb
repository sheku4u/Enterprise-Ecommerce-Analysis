# %%
# import 
import pandas as pd
from sqlalchemy import create_engine

# %%
# mysql connection
user = "root"
password = "Abhi8383055393"
host = "localhost"
port = "3306"
database = "ecommmerce_analysis"

conn_str = f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"

mysql_conn = create_engine(conn_str)

# %%
returns = pd.read_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/returns.csv")
returns

# %%
returns.to_sql("returns", mysql_conn,if_exists='replace',index=False)

# %%
returns.info()

# %%
returns.nunique()

# %%
returns = returns.drop_duplicates(subset="return_id")

# %%
returns = returns.dropna(subset="return_reason")

# %%
returns['return_date'] = pd.to_datetime(returns['return_date'] , format='mixed')

# %%
returns['refund_amount'].min()

# %%
returns = returns[returns['refund_amount'] > 0 ]

# %%
returns.info()

# %%
returns.to_sql("returns",mysql_conn,if_exists='replace',index=False)

# %%
returns.to_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/returns.csv", index=False)
