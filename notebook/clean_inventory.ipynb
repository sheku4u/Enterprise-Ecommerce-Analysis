# %%
# import 
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import datetime as dt

# %%
# mysql connection
user = "root"
password = "Abhi8383055393"
host = "localhost"
port = "3306"
database = "ecommmerce_analysis"

conn_str = f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"

mysql_conn = create_engine(conn_str)

# %%
inventory = pd.read_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/inventory.csv")
inventory.head()

# %%
inventory.info()

# %%
inventory.nunique()

# %%
inventory = inventory.drop_duplicates(subset="inventory_id")

# %%
inventory.info()

# %%
inventory[inventory['stock'] == 0 ]

# %%
# inventory added into database
inventory.to_sql("inventory", mysql_conn, if_exists='replace', index=False)
# Out:
# 14895

# %%
inventory.to_csv("C:/Users/abhis/OneDrive/Documents/abhishek/Data_Analyst_Abhishek/data_analyst/python_data/practice/enterprise ecommerce project/data/inventory.csv", index=False)
